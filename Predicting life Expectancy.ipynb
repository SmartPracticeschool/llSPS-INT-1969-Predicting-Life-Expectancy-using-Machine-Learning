# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_f58d5919c5814847a242a5c0d00c5ddb = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='LtGLLOa5tSWBAo__rSTqJNsK-QHJC-5ZB0xripe0MEl6',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_f58d5919c5814847a242a5c0d00c5ddb.get_object(Bucket='predictlifeexpectancy-donotdelete-pr-bwqwgpw3mwrpme',Key='Life Expectancy Data.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
df = pd.read_csv(body)
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
country_list = df.Country.unique()
len(country_list)
# Out:
# 193

# %%
country_list = df.Country.unique()
fill_list = ['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
       'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
       'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
       'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
       ' thinness  1-19 years', ' thinness 5-9 years',
       'Income composition of resources', 'Schooling']

# %%
for country in country_list:
    df.loc[df['Country'] == country,fill_list] = df.loc[df['Country'] == country,fill_list].interpolate()
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1987, 22)

# %%
df.rename(columns={" BMI ":"BMI",'Life expectancy ':'Life expectancy',
                  "under-five deaths ":"under-five deaths","Measles ":"Measles","Diphtheria ":"Diphtheria",
                  ' HIV/AIDS':"HIV/AIDS",
                  " thinness  1-19 years":"thinness 10-19 years"," thinness 5-9 years":"thinness 5-9 years"},inplace=True)

# %%
col_dict = {'Life expectancy':1 , 'Adult Mortality':2 ,
        'Alcohol':3 , 'percentage expenditure': 4, 'Hepatitis B': 5,
       'Measles' : 6, 'BMI': 7, 'under-five deaths' : 8, 'Polio' : 9, 'Total expenditure' :10,
       'Diphtheria':11, 'HIV/AIDS':12, 'GDP':13, 'Population' :14,
       'thinness 10-19 years' :15, 'thinness 5-9 years' :16,
       'Income composition of resources' : 17, 'Schooling' :18, 'infant deaths':19}

# %%
df1=df.dropna()

# %%
df1.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness 10-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
X = df.drop('Life expectancy', axis=1)
Y = pd.DataFrame(data=df,columns=['Life expectancy'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)
print(df.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness 10-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
numeric_features = ['Year', 'BMI',
       'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
       'under-five deaths', 'Polio', 'Total expenditure',
       'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness 10-19 years',
       'thinness 5-9 years', 'Income composition of resources', 'Schooling',
       'Measles']
categorical_features = ['Country', 'Status']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore')),
])

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median'))
   
])

# %%
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features),
        ('num', numeric_transformer, numeric_features)
    ]
)

# %%
from sklearn.ensemble import RandomForestRegressor
reg = Pipeline([
     ('preprocessor', preprocessor),
     ('RFRegressor', RandomForestRegressor())
])

# %%
reg.fit(X_train,Y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('preprocessor', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('cat', Pipeline(memory=None,
#      steps=[('onehot', OneHotEncoder(categorical_features=None, categories=None,
#        dtype=<class 'numpy.float64'>...ators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False))])

# %%
y_pred=reg.predict(X_test)

# %%
res=reg.score(X_test,Y_test)

# %%
print(res*100)
# Out:
# 95.27168652464827

# %%
from sklearn import metrics

# %%
print(np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))
# Out:
# 2.077897262902061

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %%
wml_credentials={
  "apikey": "UQo3NzkuaK47xRsqiceo3PTonhkagTo8VNjvLrsSKqg9",
  "iam_apikey_description": "Auto-generated for key 70f4ccbb-0844-4b47-8b31-9538e23e2280",
  "iam_apikey_name": "Service credentials-1",
  "iam_role_crn": "crn:v1:bluemix:public:iam::::serviceRole:Writer",
  "iam_serviceid_crn": "crn:v1:bluemix:public:iam-identity::a/293fb8a95b434e51a7b5dd1a2dff970f::serviceid:ServiceId-4cd2f07c-a4bd-4d7c-afef-906cd015bf09",
  "instance_id": "221e1d23-cce0-44f0-8046-1f7134fdb9e1",
  "url": "https://eu-gb.ml.cloud.ibm.com"
}

# %%
client= WatsonMachineLearningAPIClient(wml_credentials)

# %%
model_props={
    client.repository.ModelMetaNames.AUTHOR_NAME: "Hardik",
    client.repository.ModelMetaNames.AUTHOR_EMAIL: "hardikvagrecha@gmail.com",
    client.repository.ModelMetaNames.NAME: "Life Expectancy",
}

# %%
model_artifact=client.repository.store_model(reg,meta_props=model_props)

# %%
model_artifact['metadata']['guid']
# Out:
# 'ff93f364-c15a-44f3-8674-053885e37dd0'

# %%
guid='ff93f364-c15a-44f3-8674-053885e37dd0'

# %%
deploy=client.deployments.create(guid,name="life Expectancy")
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: 'ff93f364-c15a-44f3-8674-053885e37dd0' started
#
# #######################################################################################
#
#
# INITIALIZING
# DEPLOY_SUCCESS
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='84628635-15dc-4792-8f85-449bd67e13d2'
# ------------------------------------------------------------------------------------------------

# %%
client.deployments.list()
# Out:
# ------------------------------------  -----------------  ------  --------------  ------------------------  -----------------  -------------
# GUID                                  NAME               TYPE    STATE           CREATED                   FRAMEWORK          ARTIFACT TYPE
# 84628635-15dc-4792-8f85-449bd67e13d2  life Expectancy    online  DEPLOY_SUCCESS  2020-06-12T05:52:53.292Z  scikit-learn-0.20  model
# 381791a1-4982-4c50-ba2d-0986276bfc4c  Salary Prediction  online  DEPLOY_SUCCESS  2020-06-08T17:48:33.214Z  scikit-learn-0.20  model
# 41fcf33e-8aad-4300-aeb9-c27f77d71e8e  Salary Prediction  online  DEPLOY_SUCCESS  2020-06-08T16:17:43.101Z  scikit-learn-0.20  model
# ------------------------------------  -----------------  ------  --------------  ------------------------  -----------------  -------------

# %%
deploy
# Out:
# {'metadata': {'guid': '84628635-15dc-4792-8f85-449bd67e13d2',
#   'url': 'https://eu-gb.ml.cloud.ibm.com/v3/wml_instances/221e1d23-cce0-44f0-8046-1f7134fdb9e1/deployments/84628635-15dc-4792-8f85-449bd67e13d2',
#   'created_at': '2020-06-12T05:52:53.292Z',
#   'modified_at': '2020-06-12T05:52:53.640Z'},
#  'entity': {'runtime_environment': 'python-3.6',
#   'name': 'life Expectancy',
#   'scoring_url': 'https://eu-gb.ml.cloud.ibm.com/v3/wml_instances/221e1d23-cce0-44f0-8046-1f7134fdb9e1/deployments/84628635-15dc-4792-8f85-449bd67e13d2/online',
#   'deployable_asset': {'name': 'Life Expectancy',
#    'url': 'https://eu-gb.ml.cloud.ibm.com/v3/wml_instances/221e1d23-cce0-44f0-8046-1f7134fdb9e1/published_models/ff93f364-c15a-44f3-8674-053885e37dd0',
#    'guid': 'ff93f364-c15a-44f3-8674-053885e37dd0',
#    'created_at': '2020-06-12T05:52:53.270Z',
#    'type': 'model'},
#   'description': 'Description of deployment',
#   'status_details': {'status': 'DEPLOY_SUCCESS'},
#   'model_type': 'scikit-learn-0.20',
#   'status': 'DEPLOY_SUCCESS',
#   'type': 'online',
#   'deployed_version': {'url': 'https://eu-gb.ml.cloud.ibm.com/v3/ml_assets/models/ff93f364-c15a-44f3-8674-053885e37dd0/versions/66d4e521-886f-47a7-90f2-fa64765b4e77',
#    'guid': '66d4e521-886f-47a7-90f2-fa64765b4e77'}}}
